# %% [markdown]
# #### Text Splitting

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader("speech.txt")
loader
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_6272\1763639762.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
document=loader.load()
document
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='"LangChain is a powerful open-source framework designed to build applications \nusing large language models (LLMs) by connecting them with external data sources, \nmemory, and reasoning tools. It turns isolated AI models into interactive, \ncontext-aware systems capable of solving complex real-world tasks. \nGood morning everyone. Today, we live in a world where Artificial Intelligenceâ€”and \nspecifically Large Language Modelsâ€”can write poems, write code, and answer questions \nin seconds. But an AI model by itself is like a brilliant brain locked in a room with no doors. \nIt does not know your personal data, it cannot browse the live internet, and it forgets what \nyou told it five minutes ago. LangChain did not make AI models smarter, but it made them \nuseful. It transformed AI from a cool party trick into practical software that reads our \nfiles, automates our work, and answers our questions with real-time facts. As developers \nand thinkers, our job is no longer just wondering what AI can sayâ€”with tools like LangChain, \nit is about deciding what AI can do."')]

# %% [markdown]
# #### Recursive way to split the text in character

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=50,chunk_overlap=10)
doc=text_splitter.split_documents(document)
doc
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='"LangChain is a powerful open-source framework'),
#  Document(metadata={'source': 'speech.txt'}, page_content='framework designed to build applications'),
#  Document(metadata={'source': 'speech.txt'}, page_content='using large language models (LLMs) by connecting'),
#  Document(metadata={'source': 'speech.txt'}, page_content='them with external data sources,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='memory, and reasoning tools. It turns isolated AI'),
#  Document(metadata={'source': 'speech.txt'}, page_content='AI models into interactive,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='context-aware systems capable of solving complex'),
#  Document(metadata={'source': 'speech.txt'}, page_content='complex real-world tasks.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Good morning everyone. Today, we live in a world'),
#  Document(metadata={'source': 'speech.txt'}, page_content='a world where Artificial Intelligenceâ€”and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='specifically Large Language Modelsâ€”can write'),
#  Document(metadata={'source': 'speech.txt'}, page_content='write poems, write code, and answer questions'),
#  Document(metadata={'source': 'speech.txt'}, page_content='in seconds. But an AI model by itself is like a'),
#  Document(metadata={'source': 'speech.txt'}, page_content='is like a brilliant brain locked in a room with'),
#  Document(metadata={'source': 'speech.txt'}, page_content='room with no doors.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='It does not know your personal data, it cannot'),
#  Document(metadata={'source': 'speech.txt'}, page_content='it cannot browse the live internet, and it'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and it forgets what'),
#  Document(metadata={'source': 'speech.txt'}, page_content='you told it five minutes ago. LangChain did not'),
#  Document(metadata={'source': 'speech.txt'}, page_content='did not make AI models smarter, but it made them'),
#  Document(metadata={'source': 'speech.txt'}, page_content='useful. It transformed AI from a cool party trick'),
#  Document(metadata={'source': 'speech.txt'}, page_content='trick into practical software that reads our'),
#  Document(metadata={'source': 'speech.txt'}, page_content='files, automates our work, and answers our'),
#  Document(metadata={'source': 'speech.txt'}, page_content='our questions with real-time facts. As developers'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and thinkers, our job is no longer just wondering'),
#  Document(metadata={'source': 'speech.txt'}, page_content='wondering what AI can sayâ€”with tools like'),
#  Document(metadata={'source': 'speech.txt'}, page_content='like LangChain,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='it is about deciding what AI can do."')]

# %%
print(doc[0])
print("\n")
print(doc[1])
# Out:
# page_content='"LangChain is a powerful open-source framework' metadata={'source': 'speech.txt'}
#
#
# page_content='framework designed to build applications' metadata={'source': 'speech.txt'}

# %%
from langchain_text_splitters import CharacterTextSplitter
splitter=CharacterTextSplitter(separator="\n\n",chunk_size=50,chunk_overlap=10)
docs=text_splitter.split_documents(document)

# %%
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='"LangChain is a powerful open-source framework'),
#  Document(metadata={'source': 'speech.txt'}, page_content='framework designed to build applications'),
#  Document(metadata={'source': 'speech.txt'}, page_content='using large language models (LLMs) by connecting'),
#  Document(metadata={'source': 'speech.txt'}, page_content='them with external data sources,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='memory, and reasoning tools. It turns isolated AI'),
#  Document(metadata={'source': 'speech.txt'}, page_content='AI models into interactive,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='context-aware systems capable of solving complex'),
#  Document(metadata={'source': 'speech.txt'}, page_content='complex real-world tasks.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Good morning everyone. Today, we live in a world'),
#  Document(metadata={'source': 'speech.txt'}, page_content='a world where Artificial Intelligenceâ€”and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='specifically Large Language Modelsâ€”can write'),
#  Document(metadata={'source': 'speech.txt'}, page_content='write poems, write code, and answer questions'),
#  Document(metadata={'source': 'speech.txt'}, page_content='in seconds. But an AI model by itself is like a'),
#  Document(metadata={'source': 'speech.txt'}, page_content='is like a brilliant brain locked in a room with'),
#  Document(metadata={'source': 'speech.txt'}, page_content='room with no doors.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='It does not know your personal data, it cannot'),
#  Document(metadata={'source': 'speech.txt'}, page_content='it cannot browse the live internet, and it'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and it forgets what'),
#  Document(metadata={'source': 'speech.txt'}, page_content='you told it five minutes ago. LangChain did not'),
#  Document(metadata={'source': 'speech.txt'}, page_content='did not make AI models smarter, but it made them'),
#  Document(metadata={'source': 'speech.txt'}, page_content='useful. It transformed AI from a cool party trick'),
#  Document(metadata={'source': 'speech.txt'}, page_content='trick into practical software that reads our'),
#  Document(metadata={'source': 'speech.txt'}, page_content='files, automates our work, and answers our'),
#  Document(metadata={'source': 'speech.txt'}, page_content='our questions with real-time facts. As developers'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and thinkers, our job is no longer just wondering'),
#  Document(metadata={'source': 'speech.txt'}, page_content='wondering what AI can sayâ€”with tools like'),
#  Document(metadata={'source': 'speech.txt'}, page_content='like LangChain,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='it is about deciding what AI can do."')]

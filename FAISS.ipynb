# %% [markdown]
# #### FAISS (Facebook AI Similarity Search)
# It is a highly optimized, open-source library developed by Meta AI Research that specializes in the efficient similarity search and clustering of dense vectors.

# %%
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import OllamaEmbeddings
from langchain_text_splitters import CharacterTextSplitter

# %%
loader=TextLoader("speech.txt")
document=loader.load()
text_splitter=CharacterTextSplitter(separator=" ",chunk_size=100,chunk_overlap=10)
docs=text_splitter.split_documents(document)
len(docs)
# Out:
# 47

# %%
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='"LangChain is a powerful open-source framework designed to build applications \nusing large language'),
#  Document(metadata={'source': 'speech.txt'}, page_content='language models (LLMs) by connecting them with external data sources, \nmemory, and reasoning tools.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='tools. It turns isolated AI models into interactive, \ncontext-aware systems capable of solving'),
#  Document(metadata={'source': 'speech.txt'}, page_content='of solving complex real-world tasks. \nGood morning everyone. Today, we live in a world where'),
#  Document(metadata={'source': 'speech.txt'}, page_content='where Artificial Intelligenceâ€”and \nspecifically Large Language Modelsâ€”can write poems, write'),
#  Document(metadata={'source': 'speech.txt'}, page_content='write code, and answer questions \nin seconds. But an AI model by itself is like a brilliant brain'),
#  Document(metadata={'source': 'speech.txt'}, page_content='brain locked in a room with no doors. \nIt does not know your personal data, it cannot browse the'),
#  Document(metadata={'source': 'speech.txt'}, page_content='browse the live internet, and it forgets what \nyou told it five minutes ago. LangChain did not make'),
#  Document(metadata={'source': 'speech.txt'}, page_content='not make AI models smarter, but it made them \nuseful. It transformed AI from a cool party trick into'),
#  Document(metadata={'source': 'speech.txt'}, page_content='trick into practical software that reads our \nfiles, automates our work, and answers our questions'),
#  Document(metadata={'source': 'speech.txt'}, page_content='questions with real-time facts. As developers \nand thinkers, our job is no longer just wondering'),
#  Document(metadata={'source': 'speech.txt'}, page_content='wondering what AI can sayâ€”with tools like LangChain, \nit is about deciding what AI can'),
#  Document(metadata={'source': 'speech.txt'}, page_content='AI can do.\nLangChain serves as a generic interface for nearly any LLM, providing a centralized'),
#  Document(metadata={'source': 'speech.txt'}, page_content='development\nenvironment to build LLM applications and integrate them with external data sources and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and software workflows. \nLangChainâ€™s module-based approach allows developers and data scientists'),
#  Document(metadata={'source': 'speech.txt'}, page_content='scientists to dynamically compare different \nprompts and even different foundation models with'),
#  Document(metadata={'source': 'speech.txt'}, page_content='with minimal need to rewrite code. This modular environment \nalso allows for programs that use'),
#  Document(metadata={'source': 'speech.txt'}, page_content='that use multiple LLMs: for example, an application that uses one LLM to interpret \nuser queries and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and another LLM to author a response.\nLaunched by Harrison Chase in October 2022, LangChain enjoyed'),
#  Document(metadata={'source': 'speech.txt'}, page_content='enjoyed a meteoric rise to prominence: as of June 2023, \nit was the single fastest-growing open'),
#  Document(metadata={'source': 'speech.txt'}, page_content='open source project on Github.1 Coinciding with the momentous launch of OpenAIâ€™s \nChatGPT the'),
#  Document(metadata={'source': 'speech.txt'}, page_content='the following month, LangChain has played a significant role in making generative AI (genAI) more'),
#  Document(metadata={'source': 'speech.txt'}, page_content='more \naccessible to enthusiasts and startups in the wake of its widespread popularity. Advancements'),
#  Document(metadata={'source': 'speech.txt'}, page_content='in accessibility \nfor agentic AI are currently enabling a revolution in automation.\nLangChain can'),
#  Document(metadata={'source': 'speech.txt'}, page_content='can facilitate most use cases for LLMs and natural language processing (NLP), like chatbots,'),
#  Document(metadata={'source': 'speech.txt'}, page_content='chatbots, \nintelligent search, question-answering, summarization services or even AI agents capable'),
#  Document(metadata={'source': 'speech.txt'}, page_content='capable of robotic process \nautomation.\nLLMs are not standalone applications: they are pre-trained'),
#  Document(metadata={'source': 'speech.txt'}, page_content='statistical models that must be paired with an \napplication (and, in some cases, specific data'),
#  Document(metadata={'source': 'speech.txt'}, page_content='data sources) in order to meet their purpose.\nFor example, Chat-GPT is not an LLM: it is a chatbot'),
#  Document(metadata={'source': 'speech.txt'}, page_content='a chatbot application that, depending on the version youâ€™ve chosen, \nuses the GPT-3.5 or GPT-4'),
#  Document(metadata={'source': 'speech.txt'}, page_content='or GPT-4 language model. While itâ€™s the GPT model that interprets the userâ€™s input and composes'),
#  Document(metadata={'source': 'speech.txt'}, page_content='composes \na natural language response, itâ€™s the application that (among other things) provides an'),
#  Document(metadata={'source': 'speech.txt'}, page_content='an interface for the user \nto type and read and a UX design that governs the chatbot experience.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Even at the enterprise level, Chat-GPT is \nnot the only application using the GPT model: Microsoft'),
#  Document(metadata={'source': 'speech.txt'}, page_content='Microsoft uses GPT-4 to power Bing Chat.\nFurthermore, though foundation models (like those powering'),
#  Document(metadata={'source': 'speech.txt'}, page_content='powering LLMs) are pre-trained on massive datasets, they are \nnot omniscient. If a particular task'),
#  Document(metadata={'source': 'speech.txt'}, page_content='task requires access to specific contextual information, like internal \ndocumentation or domain'),
#  Document(metadata={'source': 'speech.txt'}, page_content='or domain expertise, LLMs must be connected to those external data sources. Even if you simply \nwant'),
#  Document(metadata={'source': 'speech.txt'}, page_content='want your model to reflect real-time awareness of current events, it requires external information:'),
#  Document(metadata={'source': 'speech.txt'}, page_content='a modelâ€™s \ninternal data is only up-to-date through the time period during which it was'),
#  Document(metadata={'source': 'speech.txt'}, page_content='it was pre-trained.\nLikewise, if a given generative AI task requires access to external software'),
#  Document(metadata={'source': 'speech.txt'}, page_content='software workflowsâ€”for example, \nif you wanted your virtual agent to integrate with Slackâ€”then'),
#  Document(metadata={'source': 'speech.txt'}, page_content='you will need a way to integrate the LLM \nwith the API for that software.\nWhile these integrations'),
#  Document(metadata={'source': 'speech.txt'}, page_content='can generally be achieved with fully manual code, orchestration frameworks such as \nLangChain and'),
#  Document(metadata={'source': 'speech.txt'}, page_content='and the IBM watsonx portfolio of artificial intelligence products greatly simplify the process.'),
#  Document(metadata={'source': 'speech.txt'}, page_content='process. \nThey also make it much easier to experiment with different LLMs to compare results, as'),
#  Document(metadata={'source': 'speech.txt'}, page_content='as different models can \nbe swapped in and out with minimal changes to code."')]

# %%
embeddings=OllamaEmbeddings(model="nomic-embed-text")
db=FAISS.from_documents(docs,embeddings)

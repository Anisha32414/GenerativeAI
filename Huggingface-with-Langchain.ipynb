# %% [markdown]
# #### Langchain_Huggingface
# langchain_huggingface, a partner package in LangChain jointly maintained by Huggingface and LangChain. This new Python package is designed to bring the power of the latest development of Huggingface into LangChain and keep it up to date.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# #### HuggingFace Endpoint
# ##### How to access HuggingFace model with API
# There are also two ways to use this class. You can specify the model with repo_id parameter. Those
# endpoints use the serverless API, which is particularly beneficial to people using pro accounts
# or enterprise hub. Still, regular users can already have access to a fair amount of request by
# connecting with their HF token in the environment where they are executing the code.

# %%
from langchain_huggingface import HuggingFaceEndpoint, ChatHuggingFace

# %%
HF_TOKEN=os.environ["HUGGINGFACEHUB_API_TOKEN"]

# %%
repo_id="google/gemma-4-31B-it"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_new_tokens=150,task="text-generation",temperature=0.7)

# %%
chat_model=ChatHuggingFace(llm=llm)

# %%
response=chat_model.invoke("What is machine learning?")
response.content

# %%
chat_model.invoke("What is generative AI?").content

# %%
from langchain_classic import LLMChain, PromptTemplate
template="""
Question:{question}
Answer:Lets think step by step
"""

prompt=PromptTemplate(template=template,input_variables=["question"])
prompt

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
chat_model.invoke("who is the president of INDIA?")

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings
model_name="BAAI/bge-small-en"
model_kwargs={"device":"cpu"}
encode_kwargs={"normalize_embeddings":True}
hf=HuggingFaceBgeEmbeddings(
    model_name=model_name,model_kwargs=model_kwargs,encode_kwargs=encode_kwargs
)

# %%
embedding=hf.embed_query("Hi this is anisha")
embedding
